# %%
import sodlab

# %%
pattern = '^instrument_file_.+\\.csv$'
input = 'C:\\Data\\projects\\gradio_test\\NGR'

recursive = True
sodlab.get_files(input, pattern, recursive)
# Out:
# ['C:\\Data\\projects\\gradio_test\\NGR\\402-U1612A-10R-1_20240215183321\\transform\\instrument_file_402-U1612A-10R-1_20240215183321.csv',
#  'C:\\Data\\projects\\gradio_test\\NGR\\402-U1612A-10R-2_20240215185105\\transform\\instrument_file_402-U1612A-10R-2_20240215185105.csv',
#  'C:\\Data\\projects\\gradio_test\\NGR\\402-U1612A-10R-3_20240215194555\\transform\\instrument_file_402-U1612A-10R-3_20240215194555.csv',
#  'C:\\Data\\projects\\gradio_test\\NGR\\402-U1612A-10R-4_20240215195940\\transform\\instrument_file_402-U1612A-10R-4_20240215195940.csv',
#  'C:\\Data\\projects\\gradio_test\\NGR\\402-U1612A-13R-1_20240215232933\\transform\\instrument_file_402-U1612A-13R-1_20240215232933.csv',
#  'C:\\Data\\projects\\gradio_test\\NGR\\402-U1612A-13R-2_20240215234422\\transform\\instrument_file_402-U1612A-13R-2_20240215234422.csv',
#  'C:\\Data\\projects\\gradio_test\\NGR\\402-U1612A-16R-1_20240216050514\\transform\\instrument_file_402-U1612A-16R-1_20240216050514.csv',
# ...
