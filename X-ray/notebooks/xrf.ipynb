# %% [markdown]
# # X-ray Fluorescence

# %%
# force Jupyter to autoreload modules when they have been edited
# this helps keep the iodp module current as it is actively developed.
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
from importlib import reload

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from iodp import utils, xrf

# %%
# Ensure we are in the PhysicalProperties root folder
if not os.getcwd().endswith("X-ray"):
    print("Current working directory:", os.getcwd())
    os.chdir("../")
    
print("New current working directory:", os.getcwd())
# Out:
# Current working directory: d:\archive\hd_files\data_analysis\50_laboratory_notebooks\SOD-Laboratory\X-ray\notebooks
# New current working directory: d:\archive\hd_files\data_analysis\50_laboratory_notebooks\SOD-Laboratory\X-ray

# %% [markdown]
# ## Reading XRF .csv files

# %%
file = './data/input/XRF/397_U1587A_30kV_1.25mA_Pd-Thick_6s_DC10mm_CC12mm_S1.csv'
df = pd.read_csv(file)
df
# Out:
#        Expedition   Site Hole  Core Type  Section A/W  Offset (mm)  CSF-A (m)  \
# 0             397  U1587    A     2    H        1   A         10.0       2.81
# 1             397  U1587    A     2    H        1   A         20.0       2.82
# 2             397  U1587    A     2    H        1   A         30.0       2.83
# 3             397  U1587    A     2    H        1   A         40.0       2.84
# 4             397  U1587    A     2    H        1   A         50.0       2.85
# ...           ...    ...  ...   ...  ...      ...  ..          ...        ...
# 22290         397  U1587    A    39    X        6   A       1430.0     365.74
# 22291         397  U1587    A    39    X        6   A       1440.0     365.75
# 22292         397  U1587    A    39    X        6   A       1450.0     365.76
# 22293         397  U1587    A    39    X        6   A       1460.0     365.77
# 22294         397  U1587    A    39    X        6   A       1470.0     365.78
#
#        CSF-B (m)  ...  Mo-Ka Area Rh-Ka-Coh Area  Rh-Ka-Inc Area  Instrument  \
# 0           2.81  ...          27          34133           66037        XRF2
# 1           2.82  ...          41          32861           64389        XRF2
# 2           2.83  ...          81          32235           63110        XRF2
# 3           2.84  ...         205          34935           68067        XRF2
# 4           2.85  ...         191          34733           71321        XRF2
# ...          ...  ...         ...            ...             ...         ...
# 22290     365.74  ...        -110          26746           43016        XRF1
# 22291     365.75  ...         124          26810           44060        XRF1
# 22292     365.76  ...        -138          25942           41418        XRF1
# 22293     365.77  ...         248          25433           41550        XRF1
# 22294     365.78  ...          -5          25262           40674        XRF1
#
#        Scan Number  Date of Measure  Time of Measure  Uploaded By  \
# 0                1       2023-04-01         09:36:24         YEON
# 1                1       2023-04-01         09:36:43         YEON
# 2                1       2023-04-01         09:37:03         YEON
# 3                1       2023-04-01         09:37:23         YEON
# 4                1       2023-04-01         09:37:42         YEON
# ...            ...              ...              ...          ...
# 22290            1       2023-03-24         15:16:28         YEON
# 22291            1       2023-03-24         15:16:46         YEON
# 22292            1       2023-03-24         15:17:04         YEON
# 22293            1       2023-03-24         15:17:22         YEON
# 22294            1       2023-03-24         15:17:40         YEON
#
#              Date Uploaded  Comment
# 0      2023-04-26 16:04:17      NaN
# 1      2023-04-26 16:04:17      NaN
# 2      2023-04-26 16:04:17      NaN
# 3      2023-04-26 16:04:17      NaN
# 4      2023-04-26 16:04:17      NaN
# ...                    ...      ...
# 22290  2023-05-02 16:42:28      NaN
# 22291  2023-05-02 16:42:28      NaN
# 22292  2023-05-02 16:42:28      NaN
# 22293  2023-05-02 16:42:28      NaN
# 22294  2023-05-02 16:42:28      NaN
#
# [22295 rows x 47 columns]

# %% [markdown]
# ## Reading XRF .spe files
#
# Note: Many of the instrument parameters can be parsed directly from the .spe filename.

# %%
file = './data/input/XRF/397-U1587A-2H-1-A_SHLF11796791!0!0!  10.0!2023-04-01!09-36-35!6!30!1250!10.0!-2.0!Pd-Thick!10.0!12.0!Run2!Rep0!Sett Middle.spe'

df = xrf.read_xrf_spe_file(file)
df
# Out:
#     core_id section_id depth run_id x_position y_position replicate_id  \
# 0         0          0  10.0      2       10.0       -2.0            0
# 1         0          0  10.0      2       10.0       -2.0            0
# 2         0          0  10.0      2       10.0       -2.0            0
# 3         0          0  10.0      2       10.0       -2.0            0
# 4         0          0  10.0      2       10.0       -2.0            0
# ..      ...        ...   ...    ...        ...        ...          ...
# 200       0          0  10.0      2       10.0       -2.0            0
# 201       0          0  10.0      2       10.0       -2.0            0
# 202       0          0  10.0      2       10.0       -2.0            0
# 203       0          0  10.0      2       10.0       -2.0            0
# 204       0          0  10.0      2       10.0       -2.0            0
#
#     slit_downcore slit_crosscore total_cps  ...    0    1    2    3    4    5  \
# 0           10.00          12.00    168809  ...    0    0    0    0    0    0
# 1           10.00          12.00    168809  ...    0    0    0    0    0    0
# 2           10.00          12.00    168809  ...    0    2    2    3    8    6
# 3           10.00          12.00    168809  ...   36   64   71   87  118  132
# 4           10.00          12.00    168809  ...  169  185  170  199  183  188
# ..            ...            ...       ...  ...  ...  ...  ...  ...  ...  ...
# 200         10.00          12.00    168809  ...   32   46   45   47   56   47
# 201         10.00          12.00    168809  ...   50   41   42   40   47   49
# 202         10.00          12.00    168809  ...   46   45   48   42   49   45
# 203         10.00          12.00    168809  ...   43   48   39   31   40   36
# 204         10.00          12.00    168809  ...   47   48   44   37   52   52
#
#        6    7     8     9
# 0      0    0     0     0
# 1      0    1     0     1
# 2     16   22    29    31
# 3    115  142   151   162
# 4    203  198   181   219
# ..   ...  ...   ...   ...
# 200   51   59    60    52
# 201   46   41    47    52
# 202   38   29    49    44
# 203   43   49    45    32
# 204   31   33  None  None
#
# [205 rows x 26 columns]

# %% [markdown]
# ## Reading XRF .axml files
#
# The .axml Baxil model files follow an XML format. Use Python's built in XML parser to pull out sections.

# %%
# Steps below print out the levels of the XML. Note: To conserve, space only one entry per level is printed.
# Use the names of the levels to query sublevels.

import xml.etree.ElementTree as ET


file_path = './data/input/XRF/30kVp_XRF2_FixedCalibration_v02.axml'

tree = ET.parse(file_path)
root = tree.getroot()

already_printed = set()
def print_xml_tree(element, level=0):
    # check if line has been printed
    msg = "  " * level + f"{element.tag}: {element.attrib}"
    if not msg in already_printed:
        print(msg)
        already_printed.add(msg)
        
    for child in element:
        print_xml_tree(child, level + 1)

print_xml_tree(root)
# Out:
# bAxil: {}
#   ExperimentalConditions: {}
#     Detector: {'Name': 'Standard 3 mm thick Si(Li) with 8 um Be window'}
#       Crystal: {}
#         Composition: {}
#         Thickness: {}
#         Density: {}
#       Absorber: {}
#         Name: {}
#     Geometry: {}
#       Source-Sample: {}
#         Angle: {}
#         Distance: {}
#         SolidAngle: {}
#       Sample-Detector: {}
#       SourceFilter: {}
#       DetectorAbsorber: {}
#       Atmosphere: {}
#     Excitation: {}
#       DIRECT_TUBE: {}
#         XRayTube: {}
#           Type: {}
#           Voltage: {}
#           Current: {}
#           Anode: {}
#             Composition: {}
#             Density: {}
#           Window: {}
#             Thickness: {}
#           TakeOffAngle: {}
#           LowEnergyCutoff: {}
#           DeltaE: {}
#           IsCalculated: {}
#           CharacteristicLines: {}
#             CharLine: {}
#           Continuum: {}
#             ContInterval: {}
#   Model: {}
#     Calibration: {}
#       Zero: {}
#         Initial: {}
#         InitialConstraint: {}
#         Fitted: {}
#         FittedConstraint: {}
#         StandardDeviation: {}
#       Gain: {}
#       Noise: {}
#       Fano: {}
#     ShapeCalibration: {'DetectorZ': '14'}
#       Step: {}
#         SFIntercept: {}
#           Initial: {}
#           InitialConstraint: {}
#           Fitted: {}
#           FittedConstraint: {}
#           StandardDeviation: {}
#         SFSlope: {}
#       Tail: {}
#         TFIntercept: {}
#         TFSlope: {}
#         TGIntercept: {}
#         TGSlope: {}
#     Continuum: {}
#       Filter: {'NumIter': '12'}
#     FitControl: {}
#       Quality: {}
#         NumberIteration: {}
#         ChiSquare: {}
#         PrevChiSquare: {}
#       StopCriteria: {}
#         MaxNumberIteration: {}
#         MinChiSquare: {}
#         MinChiSquareDiff: {}
#       WeighingMode: {}
#     ROI: {'FirstChan': '120', 'LastChan': '1220', 'Mode': '0'}
#       Fit: {}
#       Continuum: {}
#     XrayLines: {}
#       LineGroup: {'Z': '19', 'ID': '1', 'Label': 'K -K', 'RadiationType': '0', 'CreationMode': '0'}
#         Area: {}
#         StdArea: {}
#         Flags: {}
#           ProfileType: {}
#           EscPeaks: {}
#           Step: {}
#           LeftTail: {}
#           RightTail: {}
#         DeltaEnergy: {}
#         WidthFactor: {}
#         Peak: {'AnalyticalLine': '1'}
#           InitialState: {}
#           FinalState: {}
#           Label: {}
#           Energy: {}
#           TransitionProbability: {}
#           LineWidth: {}
#           RelativeIntensity: {}
#           ChiSqr: {}
#         Peak: {'AnalyticalLine': '0'}
#         EscPeak: {}
#       LineGroup: {'Z': '20', 'ID': '1', 'Label': 'Ca-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '22', 'ID': '1', 'Label': 'Ti-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '25', 'ID': '1', 'Label': 'Mn-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '26', 'ID': '1', 'Label': 'Fe-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '27', 'ID': '1', 'Label': 'Co-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '28', 'ID': '1', 'Label': 'Ni-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '29', 'ID': '1', 'Label': 'Cu-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '30', 'ID': '1', 'Label': 'Zn-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '31', 'ID': '1', 'Label': 'Ga-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '33', 'ID': '1', 'Label': 'As-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '35', 'ID': '1', 'Label': 'Br-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '37', 'ID': '1', 'Label': 'Rb-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '38', 'ID': '1', 'Label': 'Sr-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '39', 'ID': '1', 'Label': 'Y -K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '40', 'ID': '1', 'Label': 'Zr-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '41', 'ID': '1', 'Label': 'Nb-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '42', 'ID': '1', 'Label': 'Mo-K', 'RadiationType': '0', 'CreationMode': '0'}
#       LineGroup: {'Z': '45', 'ID': '1', 'Label': 'Rh-K Coh', 'RadiationType': '1', 'CreationMode': '0'}
#       LineGroup: {'Z': '45', 'ID': '1', 'Label': 'Rh-K Inc', 'RadiationType': '2', 'CreationMode': '0'}
#     AnalyticalLines: {}
#       Line: {}
#         Z: {}
#         ID: {}
#         Label: {}
#         Energy: {}
#         Continuum: {}

# %%
# Get text of a sublevel giving the whole path
txt = root.find('Model/Calibration/Gain/Initial').text
print(txt)
print()

# print the contents of all children of a sublevel
children = root.find('Model/Calibration/Gain')
for property in children:
    print(f"{property.tag}: {property.text}")
    

# use the methods below for querying. 
# See XML documentation here: # https://docs.python.org/3/library/xml.etree.elementtree.html#module-xml.etree.ElementTree
# root.iter()
# root.find()
# root.findall()
# root.findtext()
# etc.
# Out:
#  2.04000E-002
#
# Initial:  2.04000E-002
# InitialConstraint:  1.00000E-003
# Fitted:  2.03734E-002
# FittedConstraint:  1.00000E-003
# StandardDeviation:  5.53185E-007

# %%
linegroups = root.find('Model/XrayLines')
for line in linegroups:
    print(line.attrib)
# Out:
# {'Z': '19', 'ID': '1', 'Label': 'K -K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '20', 'ID': '1', 'Label': 'Ca-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '22', 'ID': '1', 'Label': 'Ti-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '25', 'ID': '1', 'Label': 'Mn-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '26', 'ID': '1', 'Label': 'Fe-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '27', 'ID': '1', 'Label': 'Co-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '28', 'ID': '1', 'Label': 'Ni-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '29', 'ID': '1', 'Label': 'Cu-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '30', 'ID': '1', 'Label': 'Zn-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '31', 'ID': '1', 'Label': 'Ga-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '33', 'ID': '1', 'Label': 'As-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '35', 'ID': '1', 'Label': 'Br-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '37', 'ID': '1', 'Label': 'Rb-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '38', 'ID': '1', 'Label': 'Sr-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '39', 'ID': '1', 'Label': 'Y -K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '40', 'ID': '1', 'Label': 'Zr-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '41', 'ID': '1', 'Label': 'Nb-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '42', 'ID': '1', 'Label': 'Mo-K', 'RadiationType': '0', 'CreationMode': '0'}
# {'Z': '45', 'ID': '1', 'Label': 'Rh-K Coh', 'RadiationType': '1', 'CreationMode': '0'}
# {'Z': '45', 'ID': '1', 'Label': 'Rh-K Inc', 'RadiationType': '2', 'CreationMode': '0'}

# %%
analytical_lines = root.find('Model/AnalyticalLines')
lines = []
for line in analytical_lines:
    entry = {}
    for property in line:
        # print(f"{child.tag}: {child.text}")
        entry[property.tag] = property.text
    
    lines.append(entry)
    
df = pd.DataFrame(lines)
df.head()
# Out:
#       Z   ID Label     Area StdArea          Energy    ChiSquare Continuum
# 0   19    1     Ka     759      45    3.31290E+000    7.72E-001       639
# 1   20    1     Ka   60773     237    3.69049E+000    4.92E+001       761
# 2   22    1     Ka     539      37    4.50888E+000    8.68E-001       482
# 3   25    1     Ka    1998      54    5.89495E+000    1.47E+000       451
# 4   26    1     Ka   23245     151    6.39950E+000    9.85E+000       511
