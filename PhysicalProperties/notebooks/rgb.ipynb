# %% [markdown]
# # RGB

# %%
# force Jupyter to autoreload modules when they have been edited
# this helps keep the iodp module current as it is actively developed.
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
from importlib import reload

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from iodp import utils

# %%
# Ensure we are in the PhysicalProperties root folder
if not os.getcwd().endswith("PhysicalProperties"):
    print("Current working directory:", os.getcwd())
    os.chdir("../")
    
print("New current working directory:", os.getcwd())
# Out:
# Current working directory: d:\archive\hd_files\data_analysis\50_laboratory_notebooks\SOD-Laboratory\PhysicalProperties\notebooks
# New current working directory: d:\archive\hd_files\data_analysis\50_laboratory_notebooks\SOD-Laboratory\PhysicalProperties

# %% [markdown]
# ## Read RGB .RGB files

# %%
file = './data/input/RGB/396-U1565A-1R-1-A_20210815110836.RGB'
df = utils.read_instrument_file(file,as_dataframe=True)
df
# Out:
#                    datetime            labelid user       text_id  \
# 0   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 1   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 2   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 3   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 4   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 5   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 6   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 7   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 8   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 9   2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 10  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 11  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 12  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 13  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 14  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 15  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 16  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 17  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 18  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 19  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
# 20  2021-08-15 11:08:36 UTC  396-U1565A-1R-1-A       SHLF11053441
#
#            instrument instrument_group observed_length comment  \
# 0   SW-2001T-L200725A             SHIL           21.00
# 1   SW-2001T-L200725A             SHIL           21.00
# 2   SW-2001T-L200725A             SHIL           21.00
# 3   SW-2001T-L200725A             SHIL           21.00
# 4   SW-2001T-L200725A             SHIL           21.00
# 5   SW-2001T-L200725A             SHIL           21.00
# 6   SW-2001T-L200725A             SHIL           21.00
# 7   SW-2001T-L200725A             SHIL           21.00
# 8   SW-2001T-L200725A             SHIL           21.00
# 9   SW-2001T-L200725A             SHIL           21.00
# 10  SW-2001T-L200725A             SHIL           21.00
# 11  SW-2001T-L200725A             SHIL           21.00
# 12  SW-2001T-L200725A             SHIL           21.00
# 13  SW-2001T-L200725A             SHIL           21.00
# 14  SW-2001T-L200725A             SHIL           21.00
# 15  SW-2001T-L200725A             SHIL           21.00
# 16  SW-2001T-L200725A             SHIL           21.00
# 17  SW-2001T-L200725A             SHIL           21.00
# 18  SW-2001T-L200725A             SHIL           21.00
# 19  SW-2001T-L200725A             SHIL           21.00
# 20  SW-2001T-L200725A             SHIL           21.00
#
#    sub_sample_width decimate_interval   decimate_method  \
# 0               2.0               1.0  interval-average
# 1               2.0               1.0  interval-average
# 2               2.0               1.0  interval-average
# 3               2.0               1.0  interval-average
# 4               2.0               1.0  interval-average
# 5               2.0               1.0  interval-average
# 6               2.0               1.0  interval-average
# 7               2.0               1.0  interval-average
# 8               2.0               1.0  interval-average
# 9               2.0               1.0  interval-average
# 10              2.0               1.0  interval-average
# 11              2.0               1.0  interval-average
# 12              2.0               1.0  interval-average
# 13              2.0               1.0  interval-average
# 14              2.0               1.0  interval-average
# 15              2.0               1.0  interval-average
# 16              2.0               1.0  interval-average
# 17              2.0               1.0  interval-average
# 18              2.0               1.0  interval-average
# 19              2.0               1.0  interval-average
# 20              2.0               1.0  interval-average
#
#                                         config positions_excluded  \
# 0   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 1   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 2   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 3   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 4   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 5   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 6   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 7   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 8   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 9   c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 10  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 11  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 12  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 13  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 14  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 15  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 16  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 17  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 18  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 19  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
# 20  c:\ims\config_shil\i_pi_ajai-cv-l107cl.ini              FALSE
#
#    positions_specified offset    red  green  blue
# 0                FALSE   0.50   87.7   76.5  64.1
# 1                FALSE   1.50  114.1   95.7  76.4
# 2                FALSE   2.50  112.4   93.8  75.0
# 3                FALSE   3.50  116.6   98.1  79.2
# 4                FALSE   4.50  117.2   98.6  79.7
# 5                FALSE   5.50  115.6   96.8  78.0
# 6                FALSE   6.50  116.0   97.7  79.3
# 7                FALSE   7.50  119.1  101.0  83.1
# 8                FALSE   8.50  119.6  102.2  84.8
# 9                FALSE   9.50  117.2   99.6  82.5
# 10               FALSE  10.50  113.8   96.5  79.3
# 11               FALSE  11.50  116.5   98.8  80.7
# 12               FALSE  12.50  114.3   96.9  79.5
# 13               FALSE  13.50  107.7   90.1  73.5
# 14               FALSE  14.50  108.2   91.8  75.4
# 15               FALSE  15.50  107.5   90.7  74.2
# 16               FALSE  16.50   82.8   77.8  69.9
# 17               FALSE  17.50   81.5   82.1  78.1
# 18               FALSE  18.50   73.1   69.1  63.2
# 19               FALSE  19.50  100.6   88.9  77.8
# 20               FALSE  20.50   97.9   83.2  69.4

# %% [markdown]
# ## Read RGB .ini files

# %%
file = './data/input/RGB/i_pi_ajai-cv-l107cl.ini'
df = utils.read_instrument_ini(file, as_dataframe=True)
df
# Out:
#                                                                      value
# key
# mgi rwa section options  2.0.1 %04Y%02m%02d %02H%02M%S%25u*~|.%d*~|....
# ims framework-major                                                     11
# ims framework-minor                                                      1
# plugin-major                                                             0
# plugin-minor                                                             0
# ...                                                                    ...
# user.vcds.archive?                                                    TRUE
# user.vcds.print?                                                     FALSE
# user.vcds.mode                                                Section Half
# user.vcds.test image
# user.vcds.log folder                            C:\IMS\RESOURCES\TEMPLATES
#
# [175 rows x 1 columns]
